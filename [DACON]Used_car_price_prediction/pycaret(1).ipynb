# %%
import pandas as pd
import numpy as np

# %%
train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")

# %%
train_df = train_df.drop('id', axis = 1)
test_df = test_df.drop('id', axis = 1)

# %%
test_df.loc[142, 'engine'] = '8-cylinder(V8)'

# %%
train_df['engine'] = train_df.engine.replace('4-cylinder(H4)', '4-cylinder(I4)')

# %%
train_df.engine.unique(), test_df.engine.unique()
# Out:
# (array(['4-cylinder(I4)', '6-cylinder(V6)', '8-cylinder(V8)',
#         '6-cylinder(I6)', '5-cylinder(I5)', '3-cylinder(I3)',
#         '2-cylinder(I2)'], dtype=object),
#  array(['4-cylinder(I4)', '6-cylinder(V6)', '6-cylinder(I6)',
#         '8-cylinder(V8)', '5-cylinder(I5)', '2-cylinder(I2)',
#         '3-cylinder(I3)'], dtype=object))

# %%
train_df.loc[train_df.year == 1218, 'year'] = 2001
train_df.loc[train_df.year == 1217, 'year'] = 2001

# %%
test_df.loc[test_df.year == 1324, 'year'] = 2001
test_df.loc[test_df.year == 2626, 'year'] = 1994
test_df.loc[test_df.year == 1726, 'year'] = 1994

# %%
import re

def apply_brand(x):
    x = re.sub('[^a-zA-Z]', '', x)
    
    return x

def preprocessing_title(data):
    '''title 전처리 함수'''
    
    # 'brand' 파생변수 생성
    data['brand'] = data['title'].apply(lambda x : x.split()[0])
    data['brand'] = data['brand'].apply(apply_brand)
    # title 삭제
    data = data.drop('title', axis=1)
    
    return data

# %%
train_df = preprocessing_title(train_df)
test_df = preprocessing_title(test_df)

# %%
test_df.loc[test_df.brand == 'Fiat', 'brand'] = 'Peugeot'

train_df.loc[train_df.brand == 'Jaguar', 'brand'] = 'Toyota'
train_df.loc[train_df.brand == 'Lincoln', 'brand'] = 'Land'
train_df.loc[train_df.brand == 'Isuzu', 'brand'] = 'DAF'
train_df.loc[train_df.brand == 'IVM', 'brand'] = 'Nissan'
train_df.loc[train_df.brand == 'Dodge', 'brand'] = 'Toyota'
train_df.loc[train_df.brand == 'GMC', 'brand'] = 'Toyota'
train_df.loc[train_df.brand == 'Scania', 'brand'] = 'Volvo'
train_df.loc[train_df.brand == 'GAC', 'brand'] = 'Toyota'
train_df.loc[train_df.brand == 'IVECO', 'brand'] = 'Toyota'
train_df.loc[train_df.brand == 'MANVOLKSWAGEN', 'brand'] = 'MercedesBenz'
train_df.loc[train_df.brand == 'ALPINA', 'brand'] = 'Mack'
train_df.loc[train_df.brand == 'Bentley', 'brand'] = 'Land'
train_df.loc[train_df.brand == 'JMC', 'brand'] = 'Toyota'
train_df.loc[train_df.brand == 'Audi', 'brand'] = 'MercedesBenz'

# %%
# location의 공백과 State를 제거하는 함수
def clean_location(x):
    '''location 정리 함수'''
    x = x.replace(' ', '')
    x = x.replace('State', '')
    return x

# %%
train_df.location = train_df.location.apply(clean_location)
test_df.location = test_df.location.apply(clean_location)

# %%
test_df.loc[test_df.location == 'Mushine', 'location'] = 'Lagos'
test_df.loc[test_df.location == 'Arepoogunstate', 'location'] = 'Lagos'

train_df.loc[train_df.location == 'FCT', 'location'] = 'Lagos'
train_df.loc[train_df.location == 'Accra', 'location'] = 'Lagos'
train_df.loc[train_df.location == 'Adamawa', 'location'] = 'Lagos'

# %%
def apply_paint(x):
    x = re.sub('[^a-zA-Z]', '', x)
    x = x.lower()
    
    if x.find('black') >= 0:
        x = 'black'
    elif x.find('white') >= 0:
        x = 'white'
    elif (x.find('grey') >= 0) | (x.find('gray') >= 0):
        x = 'gray'
    elif (x.find('silver') >= 0) | (x.find('sliver') >= 0):
        x = 'silver'
    elif x.find('blue') >= 0:
        x = 'blue'
    elif x.find('red') >= 0:
        x = 'red'
    elif x.find('gold') >= 0:
        x = 'gold'
    elif x.find('green') >= 0:
        x = 'green'
    else:
        x = 'others'
        
    return x

def preprocessing_paint(data):
    '''paint 전처리 함수'''
    
    data.paint = data.paint.apply(apply_paint)
    
    return data

# %%
train_df = preprocessing_paint(train_df)
test_df = preprocessing_paint(test_df)

# %%
train_y = train_df.loc[:, ['target']]
#train_X = train_df.drop('target', axis=1)
train_X = train_df.copy()

# %%
encoded_train_X = pd.get_dummies(train_X, ['location', 'isimported', 'engine', 'transmission', 'fuel', 'paint', 'brand'])
encoded_test_X = pd.get_dummies(test_df, ['location', 'isimported', 'engine', 'transmission', 'fuel', 'paint', 'brand'])

# %%
from sklearn.preprocessing import MinMaxScaler

mms_train = MinMaxScaler()

norm_encoded_train_X = mms_train.fit_transform(encoded_train_X, encoded_train_X['target'])

mms_test = MinMaxScaler()

norm_encoded_test_X = mms_test.fit_transform(encoded_test_X)

# %%
norm_encoded_train_X
# Out:
# array([[1.85116912e-02, 9.00000000e-01, 8.86608916e-02, ...,
#         1.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.01284080e-05, 9.75000000e-01, 2.17992837e-01, ...,
#         1.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [8.41579545e-02, 8.00000000e-01, 6.35965611e-02, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        ...,
#        [9.80450147e-02, 7.75000000e-01, 2.01517217e-02, ...,
#         1.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.48153287e-01, 8.25000000e-01, 9.30053755e-02, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 4.50000000e-01, 6.42649433e-02, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00]])

# %%
from pycaret.regression import *
# Out:
# D:\Users\USER\anaconda3\envs\pycaret\lib\site-packages\pycaret\loggers\mlflow_logger.py:14: FutureWarning: MLflow support for Python 3.6 is deprecated and will be dropped in an upcoming release. At that point, existing Python 3.6 workflows that use MLflow will continue to work without modification, but Python 3.6 users will no longer get access to the latest MLflow features and bugfixes. We recommend that you upgrade to Python 3.7 or newer.
#   import mlflow

# %%
py_reg = setup(encoded_train_X, target = 'target', session_id = 42, silent = True)
# Out:
# <style  type="text/css" >
# #T_c11da212_e2d4_11ec_b563_2cfda15cf7e3row42_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3row0_col1" class="data row0 col1" >42</td>
#             </tr>
#             <tr>
#                         <th id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3row1_col1" class="data row1 col1" >target</td>
#             </tr>
#             <tr>
#                         <th id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3row2_col0" class="data row2 col0" >Original Data</td>
#                         <td id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3row2_col1" class="data row2 col1" >(1015, 58)</td>
#             </tr>
#             <tr>
#                         <th id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3row3_col0" class="data row3 col0" >Missing Values</td>
#                         <td id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3row3_col1" class="data row3 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3row4_col0" class="data row4 col0" >Numeric Features</td>
#                         <td id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3row4_col1" class="data row4 col1" >57</td>
#             </tr>
#             <tr>
#                         <th id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3row5_col0" class="data row5 col0" >Categorical Features</td>
#                         <td id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3row5_col1" class="data row5 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3row6_col0" class="data row6 col0" >Ordinal Features</td>
#                         <td id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3row6_col1" class="data row6 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3row7_col0" class="data row7 col0" >High Cardinality Features</td>
#                         <td id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3row8_col0" class="data row8 col0" >High Cardinality Method</td>
#                         <td id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3row8_col1" class="data row8 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3row9_col0" class="data row9 col0" >Transformed Train Set</td>
#                         <td id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3row9_col1" class="data row9 col1" >(710, 55)</td>
#             </tr>
#             <tr>
#                         <th id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3row10_col0" class="data row10 col0" >Transformed Test Set</td>
#                         <td id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3row10_col1" class="data row10 col1" >(305, 55)</td>
#             </tr>
#             <tr>
#                         <th id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#                         <td id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3row11_col1" class="data row11 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#                         <td id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3row12_col1" class="data row12 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3row13_col0" class="data row13 col0" >Fold Generator</td>
#                         <td id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3row13_col1" class="data row13 col1" >KFold</td>
#             </tr>
#             <tr>
#                         <th id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3row14_col0" class="data row14 col0" >Fold Number</td>
#                         <td id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3row14_col1" class="data row14 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3row15_col0" class="data row15 col0" >CPU Jobs</td>
#                         <td id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3row15_col1" class="data row15 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3row16_col0" class="data row16 col0" >Use GPU</td>
#                         <td id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3row16_col1" class="data row16 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3row17_col0" class="data row17 col0" >Log Experiment</td>
#                         <td id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3row18_col0" class="data row18 col0" >Experiment Name</td>
#                         <td id="T_c11da212_e2d4_11ec_b563_2cfda15cf7e3row18_col1" cl

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3 th {
#           text-align: left;
#     }#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row0_col0,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row1_col0,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row1_col1,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row1_col2,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row1_col3,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row1_col4,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row1_col5,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row1_col6,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row2_col0,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row2_col1,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row2_col2,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row2_col3,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row2_col4,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row2_col5,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row2_col6,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row3_col0,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row3_col1,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row3_col2,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row3_col3,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row3_col4,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row3_col5,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row3_col6,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row4_col0,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row4_col1,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row4_col2,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row4_col3,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row4_col4,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row4_col5,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row4_col6,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row5_col0,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row5_col1,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row5_col2,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row5_col3,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row5_col4,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row5_col5,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row5_col6,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row6_col0,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row6_col1,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row6_col2,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row6_col3,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row6_col4,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row6_col5,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row6_col6,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row7_col0,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row7_col1,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row7_col2,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row7_col3,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row7_col4,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row7_col5,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row7_col6,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row8_col0,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row8_col1,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row8_col2,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row8_col3,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row8_col4,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row8_col5,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row8_col6,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row9_col0,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row9_col1,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row9_col2,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row9_col3,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row9_col4,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row9_col5,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row9_col6,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row10_col0,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row10_col1,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row10_col2,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row10_col3,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row10_col4,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row10_col5,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row10_col6,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row11_col0,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row11_col1,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row11_col2,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row11_col3,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row11_col4,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row11_col5,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row11_col6,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row12_col0,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row12_col1,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row12_col2,#T_d2475c ...
#             text-align:  left;
#             text-align:  left;
#         }#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row0_col1,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row0_col2,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row0_col3,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row0_col4,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row0_col5,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row0_col6{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row0_col7,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row1_col7,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row2_col7,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row3_col7,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row4_col7,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row5_col7,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row6_col7,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row7_col7,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row8_col7,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row10_col7,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row11_col7,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row12_col7,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row13_col7,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row14_col7,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row15_col7,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row16_col7,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row17_col7,#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row18_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_d2475c98_e2d4_11ec_806b_2cfda15cf7e3row9_col7{
#             text-align:  left;
#             text-align:  left;
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=-1, oob_score=False,
#                       random_state=42, verbose=0, warm_start=False)

# %%
rf = create_model('rf', verbose=False)
gbr = create_model('gbr', verbose=False)
catboost = create_model('catboost', verbose=False)

# %%
blended_model = blend_models(estimator_list = [rf, gbr, catboost])
# Out:
# <style  type="text/css" >
# #T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row10_col0,#T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row10_col1,#T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row10_col2,#T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row10_col3,#T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row10_col4,#T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row10_col5{
#             background:  yellow;
#         }</style><table id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr>    <tr>        <th class="index_name level0" >Fold</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row0_col0" class="data row0 col0" >2839085.9177</td>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row0_col1" class="data row0 col1" >24621413922858.0156</td>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row0_col2" class="data row0 col2" >4961996.9693</td>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row0_col3" class="data row0 col3" >0.7843</td>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row0_col4" class="data row0 col4" >0.4370</td>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row0_col5" class="data row0 col5" >0.3773</td>
#             </tr>
#             <tr>
#                         <th id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row1_col0" class="data row1 col0" >2460719.1883</td>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row1_col1" class="data row1 col1" >24659131029439.3281</td>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row1_col2" class="data row1 col2" >4965796.1124</td>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row1_col3" class="data row1 col3" >0.6231</td>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row1_col4" class="data row1 col4" >0.4520</td>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row1_col5" class="data row1 col5" >0.4348</td>
#             </tr>
#             <tr>
#                         <th id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row2_col0" class="data row2 col0" >2309092.3406</td>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row2_col1" class="data row2 col1" >21459098895649.1016</td>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row2_col2" class="data row2 col2" >4632396.6686</td>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row2_col3" class="data row2 col3" >0.6174</td>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row2_col4" class="data row2 col4" >0.3473</td>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row2_col5" class="data row2 col5" >0.2995</td>
#             </tr>
#             <tr>
#                         <th id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row3_col0" class="data row3 col0" >2936406.1209</td>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row3_col1" class="data row3 col1" >101617323760680.6719</td>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row3_col2" class="data row3 col2" >10080541.8386</td>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row3_col3" class="data row3 col3" >0.5691</td>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row3_col4" class="data row3 col4" >0.4391</td>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row3_col5" class="data row3 col5" >0.3545</td>
#             </tr>
#             <tr>
#                         <th id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row4_col0" class="data row4 col0" >3902893.6969</td>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row4_col1" class="data row4 col1" >168687713852233.8125</td>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row4_col2" class="data row4 col2" >12987983.4406</td>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row4_col3" class="data row4 col3" >0.5547</td>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row4_col4" class="data row4 col4" >0.4740</td>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row4_col5" class="data row4 col5" >0.3495</td>
#             </tr>
#             <tr>
#                         <th id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row5_col0" class="data row5 col0" >2865002.8312</td>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row5_col1" class="data row5 col1" >33360276081414.8672</td>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row5_col2" class="data row5 col2" >5775835.5310</td>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row5_col3" class="data row5 col3" >0.7574</td>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row5_col4" class="data row5 col4" >0.3896</td>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row5_col5" class="data row5 col5" >0.3399</td>
#             </tr>
#             <tr>
#                         <th id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row6_col0" class="data row6 col0" >1594977.7855</td>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row6_col1" class="data row6 col1" >9289106444641.9785</td>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row6_col2" class="data row6 col2" >3047803.5443</td>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row6_col3" class="data row6 col3" >0.7886</td>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row6_col4" class="data row6 col4" >0.2980</td>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row6_col5" class="data row6 col5" >0.2708</td>
#             </tr>
#             <tr>
#                         <th id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row7_col0" class="data row7 col0" >1933036.4167</td>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row7_col1" class="data row7 col1" >13483651847932.4297</td>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row7_col2" class="data row7 col2" >3672009.2385</td>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row7_col3" class="data row7 col3" >0.8099</td>
#                         <td id="T_e1ce3c40_e2d4_11ec_953c_2cfda15cf7e3row7_col4

# %%
final_model = finalize_model(blended_model)
prediction = predict_model(final_model, data = encoded_test_X)

# %%
y_pred = prediction['Label']

# %%
submission = pd.read_csv('sample_submission.csv')
submission['target'] = y_pred
submission.head()
# Out:
#    id        target
# 0   0  1.828990e+07
# 1   1  5.452166e+06
# 2   2  6.524041e+06
# 3   3  1.544654e+06
# 4   4  2.550157e+06

# %%
submission.to_csv('submit5.csv', index=False)
